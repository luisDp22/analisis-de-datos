# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np
import seaborn as ans
import pandas as pd

# %%
df = pd.read_csv("framingham.csv")
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.plot.scatter(x="sysBP", y="diaBP")
plt.show()

# %%
df.columns
df.info
df.describe
# Out:
# <bound method NDFrame.describe of       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
regresion = linear_model.LinearRegression()

# %%
lcd = df["sysBP"].values.reshape((-1,1))

# %%
modelo = regresion.fit(lcd, df["diaBP"])
print("Interseccion (b)", modelo.intercept_)
print("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) 26.812209130130597
# Pendiente (m) [0.42372675]

# %%
entrada = [[90],[175],[200],[250],[280],[300]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [ 64.94761635 100.96438983 111.5575585  132.74389584 145.45569825
#  153.93023318]

# %%
df.plot.scatter(x="sysBP", y="diaBP", label='Datos Originales')
plt.scatter(entrada, predicciones, color='red')
plt.plot(entrada, predicciones, color='black', label='Linea de regresión')
plt.xlabel('sysBP')
plt.ylabel('diaBP')
plt.legend()
plt.show()
